# %% [markdown]
# # Examples of feature set usage:

# %%
from features_set import features_set
import pandas as pd

# %%
# set up the parameters
parameters = {
    'feature_path': "C:/Users/e.lavrova/Downloads/CLEAN_OS_sensible_py_115_no_asymmetric_wav.csv", # path to csv/xls file with features
    'outcome_path': "C:/Users/e.lavrova/Downloads/soramic_extended_new.xlsx", #path to csv/xls file with outcome
    'patient_column': 'Patient', # name of column with patient id
    'patient_in_outcome_column': 'Patient1', # name of column with patient id in clinical data file
    'outcome_column': '1yearsurvival' # name of outcome column
}

# %%
# initialize feature set
fs = features_set(**parameters)

# %%
# excluding patients with unknown outcome (in case they are represented)
fs.handle_nan(axis=0)

# %%
# checking class labels and patients' names
print ('Class labels: ', fs._class_label)
print ('Patients names: ', fs._patient_name)
# Out:
# Class labels:  ['1' '0']
# Patients names:  ['1001002', '1001003', '1001005', '1001006', '1001007', '1001008', '1001009', '1001010', '1001015', '1001017', '1001018', '1001019', '1001023', '1001024', '1001025', '1001026', '1001027', '1001028', '1001030', '1001031', '1001032', '1001034', '1001036', '1001037', '1001038', '1001040', '1001041', '1001047', '1001049', '1001050', '1001051', '1001052', '1001053', '1001054', '1001055', '1001056', '1001057', '1001058', '1001061', '1001065', '1001066', '1001071', '1001072', '1001073', '1001074', '1001075', '1001078', '1001079', '1001081', '1001082', '1001083', '1001084', '1001086', '1001087', '1001088', '1001089', '1001090', '1001091', '1001092', '1001093', '1001096', '1001098', '1001100', '1001101', '1001103', '1001104', '1001105', '1001106', '1001107', '1001108', '1001109', '1001110', '1001111', '1001112', '1001113', '1001114', '1001115', '1001116', '1001117', '1001118', '1001119', '1001121', '1001122', '1001123', '1001124', '1001125', '1001126', '1001127', '1001128', '1001129', '1001130', '1001131', '1001132', '1001133', '1001135', '1001136', '1001137', '1001138', '1001139', '1010002', '1010003', '1010004', '1010006', '1010007', '1010008', '1010009', '1010010', '1010011', '1011001', '1011002', '1011003', '1011004', '1011005', '1011007', '1011008', '1011010', '1022001', '1022002', '1102001', '1102002', '1102003', '1201001', '1201002', '1201003', '1201004', '1201005', '1201006', '1201007', '1201008', '1201009', '1201011', '1201014', '1201015', '1201017', '1201018', '1201019', '1201020', '1201021', '1201022', '1203002', '1301003', '1301005', '1301008', '1301009', '1301010', '1301011', '1301012', '1301013', '1301014', '1301015', '1301016', '1301017', '1301021', '1301022', '1301023', '1301025', '1301027', '1301028', '1301031', '1301033', '1301035', '1301038', '1301039', '1301040', '1301043', '1301045', '1301048', '1301049', '1301050', '1301051', '1301052', '1301053', '1301057', '1301058', '1301062', '1301065', '1301068', '1401002', '1401003', '1403001', '1403003', '1403004', '1403006', '1403009', '1403012', '1403014', '1403015', '1403016', '1403018', '1403019', '1403023', '1403024', '1403026', '1403027', '1501002', '1501004', '1501006', '1501007', '1501010', '1501011', '1501013', '1601001', '1601004', '1601005', '1601006', '1601007', '1601012', '1601013', '1601014', '1601016', '1601019', '1601025', '1601027', '1601030', '1701002', '1701003', '1701004', '1701005', '1701007', '1701010', '1802001', '1802002', '1802003', '1802004', '1802005', '1802006', '1804001', '1804002', '1804004', '1806001', '1806002', '1806003', '1810001', '1810004', '1810005', '1810007', '1810008', '1810009', '1810010', '1812002', '1812004', '1901001', '1901002', '1901005', '1901006', '1901009', '1901013', '1901014', '1901018', '1901021', '1901022', '1901027', '1902004', '1902008', '1902013', '1903001', '1903002', '1903003', '1903004', '1903005', '1903006', '1903007', '1903008', '1903009', '1903011', '1903013', '1903018', '1903019', '1903020', '1903022', '1903023', '1903024', '1903028', '1903029', '1903031', '1903032', '1903034', '1903035', '1903036', '1904002', '1904003', '1904004', '1904006', '1904009', '1905001', '1905004', '1905005', '1905006', '1905007', '2203001', '2203002', '2203007', '2203008', '2203009', '2203011', '2203013', '2205010', '2205011', '2205012', '2205014', '2205016', '2206001', '2206003', '2206007', '2209002', '2209003', '2209004', '2209006', '2301002', '2301003', '2301004', '2301005', '2301006', '2301008', '2301009', '2301010', '2301011', '2301012', '2301014', '2301015', '2301016']

# %%
fs._feature_outcome_dataframe
# Out:
#          original_shape_Elongation  original_shape_Flatness  \
# Patient
# 1001002                   0.865951                 0.666800
# 1001003                   0.726654                 0.638583
# 1001005                   0.655049                 0.343380
# 1001006                   0.803802                 0.634070
# 1001007                   0.767257                 0.655277
# ...                            ...                      ...
# 2301011                   0.892328                 0.817898
# 2301012                   0.884221                 0.726464
# 2301014                   0.878420                 0.507671
# 2301015                   0.727891                 0.662404
# 2301016                   0.802694                 0.000000
#
#          original_shape_LeastAxisLength  original_shape_MajorAxisLength  \
# Patient
# 1001002                       30.252209                       45.369211
# 1001003                       71.467569                      111.915836
# 1001005                       75.834585                      220.847255
# 1001006                       93.408654                      147.316030
# 1001007                       17.342413                       26.465775
# ...                                 ...                             ...
# 2301011                       77.785522                       95.104188
# 2301012                       12.454119                       17.143475
# 2301014                       12.157692                       23.947998
# 2301015                       15.374601                       23.210299
# 2301016                        0.000000                       18.692291
#
#          original_shape_Maximum2DDiameterColumn  \
# Patient
# 1001002                               51.613952
# 1001003                              105.422958
# 1001005                              213.714763
# 1001006                              144.253250
# 1001007                               32.649655
# ...                                         ...
# 2301011                              112.008928
# 2301012                               18.867962
# 2301014                               23.430749
# 2301015                               23.323808
# 2301016                               16.000000
#
#          original_shape_Maximum2DDiameterRow  \
# Patient
# 1001002                            54.671748
# 1001003                           133.775932
# 1001005                           175.801024
# 1001006                           142.341139
# 1001007                            26.248809
# ...                                      ...
# 2301011                           102.489024
# 2301012                            19.849433
# 2301014                            26.925824
# 2301015                            26.907248
# 2301016                            18.000000
#
#          original_shape_Maximum2DDiameterSlice  \
# Patient
# 1001002                              44.271887
# 1001003                             120.415946
# 1001005                             229.617073
# 1001006                             166.973052
# 1001007                              28.653098
# ...                                        ...
# 2301011                             115.831775
# 2301012                              19.416488
# 2301014                              26.925824
# 2301015                              24.351591
# 2301016                              18.973666
#
#          original_shape_Maximum3DDiameter  original_shape_MeshVolume  \
# Patient
# 1001002                         58.086143               3.370521e+04
# 1001003                        136.462449               3.769252e+05
# 1001005                        257.015564               1.045192e+06
# 1001006                        186.016128               1.134747e+06
# 1001007                         33.955854               6.106250e+03
# ...                                   ...                        ...
# 2301011                        116.382988               4.487692e+05
# 2301012                         21.610183               2.126875e+03
# 2301014                         28.722813               3.931667e+03
# 2301015                         27.730849               4.139792e+03
# 2301016                         18.973666               1.032083e+03
#
#          original_shape_MinorAxisLength  ...  \
# Patient                                  ...
# 1001002                       39.287515  ...
# 1001003                       81.324121  ...
# 1001005                      144.665706  ...
# 1001006                      118.412857  ...
# 1001007                       20.306046  ...
# ...                                 ...  ...
# 2301011                       84.864173  ...
# 2301012                       15.158623  ...
# 2301014                       21.036393  ...
# 2301015                       16.894560  ...
# 2301016                       15.004190  ...
#
#          wavelet_LLL_gldm_SmallDependenceHighGrayLevelEmphasis  \
# Patient
# 1001002                                           2.736508
# 1001003                                          10.133377
# 1001005                                           2.123760
# 1001006                                          14.226541
# 1001007                                           0.947393
# ...                                                    ...
# 2301011                                         115.054695
# 2301012                                           2.559627
# 2301014                                           5.019592
# 2301015                                         109.105144
# 2301016                                           2.709626
#
#          wavelet_LLL_gldm_SmallDependenceLowGrayLevelEmphasis  \
# Patient
# 1001002                                           0.001364
# 1001003                                           0.000113
# 1001005                                           0.000374
# 1001006                                           0.000087
# 1001007                                           0.004886
# ...                                                    ...
# 2301011                                           0.000137
# 2301012                                           0.016313
# 2301014                                           0.010349
# 2301015                                           0.002012
# 2301016                                           0.017679
#
#          wavelet_LLL_ngtdm_Busyness  wavelet_LLL_ngtdm_Coarseness  \
# Patient
# 1001002                    3.660153                      0.001633
# 1001003                    6.828208                      0.000170
# 1001005                   59.720087                      0.000053
# 1001006                   13.085403                      0.000060
# 1001007                    4.576328                      0.006294
# ...                             ...                           ...
# 2301011                    2.605704                      0.000098
# 2301012                    1.683306                      0.019041
# 2301014                    1.032071                      0.011977
# 2301015                    0.078855                      0.009498
# 2301016                    1.262041                      0.045762
#
#          wavelet_LLL_ngtdm_Complexity  wavelet_LLL_ngtdm_Contrast  \
# Patient
# 1001002                     67.177012                    0.024907
# 1001003                    209.523297                    0.004694
# 1001005                     77.658136                    0.004229
# 1001006                    378.748494                    0.005420
# 1001007                     17.141073                    0.032859
# ...                               ...                         ...
# 2301011                   2664.196813                    0.023955
# 2301012                     23.964324                    0.060162
# 2301014                     58.211213                    0.045622
# 2301015                   1039.655329                    0.071019
# 2301016                     10.112883                    0.063763
#
#          wavelet_LLL_ngtdm_Strength  CS       OS  1yearsurvival
# Patient
# 1001002                    0.144883   1   5.6066              1
# 1001003                    0.145489   1  16.3279              1
# 1001005                    0.012770   0  69.3115              1
# 1001006                    0.062114   1  27.1475              1
# 1001007                    0.135157   1  28.2623              1
# ...                             ...  ..      ...            ...
# 2301011                    0.301622   1  32.8525              1
# 2301012                    0.513096   0  28.0000              1
# 2301014                    0.716068   1  18.3607              1
# 2301015                    9.265699   0  21.2459              1
# 2301016                    0.678152   1  13.6066              1
#
# [323 rows x 563 columns]

# %%
# visualization of feature values distribution in classes (in .html report)
fs.plot_binary_distribution(fs._feature_column[:100])

# %% [markdown]
# Example of plotted distributions of feature values in classes:
# ![](./data/images/distr.png)

# %%
# visualization of feature mutual (Spearman) correlation coefficient matrix (in .html report)
fs.plot_correlation_matrix(fs._feature_column[:100])

# %% [markdown]
# Example of feature correlation matrix:
# ![](./data/images/corr.png)

# %%
# visualization of Mann-Whitney Bonferroni corrected p-values for binary classes test (in .html report)
fs.plot_MW_p(fs._feature_column[:100])

# %% [markdown]
# Example of Mann-Whitney p-values:
# ![](./data/images/p_MW.png)

# %%
# visualization of univariate ROC-curves (in .html report)
fs.plot_univariate_roc(fs._feature_column[:100])

# %% [markdown]
# Example of univariate feature ROC:
# ![](./data/images/roc.png)

# %%
# calculation of basic statistics for each feature (in .xlsx):
# number of NaN, mean, std, min, max; if applicable: MW-p, univariate ROC AUC, volume correlation
fs.calculate_basic_stats(volume_feature='original_shape_VoxelVolume')

# %%
# checking the excel table
print('Basic statistics for each feature')
pd.read_excel('./data/features/features_basic_stats.xlsx')
# Out:
# Basic statistics for each feature
#                                              Unnamed: 0  NaN         Mean  \
# 0                             original_shape_Elongation    0     0.720328
# 1                               original_shape_Flatness    0     0.559677
# 2                        original_shape_LeastAxisLength    0    32.055804
# 3                        original_shape_MajorAxisLength    0    61.595666
# 4                original_shape_Maximum2DDiameterColumn    0    63.064956
# ...                                                 ...  ...          ...
# 1213  wavelet-LLL_gldm_LargeDependenceLowGrayLevelEm...    0     1.646810
# 1214              wavelet-LLL_gldm_LowGrayLevelEmphasis    0     0.007969
# 1215           wavelet-LLL_gldm_SmallDependenceEmphasis    0     0.313546
# 1216  wavelet-LLL_gldm_SmallDependenceHighGrayLevelE...    0  2431.019809
# 1217  wavelet-LLL_gldm_SmallDependenceLowGrayLevelEm...    0     0.000440
#
#               Std        Min          Max  p_MW_corrected  univar_auc  \
# 0        0.161721   0.062127     0.974104        1.000000    0.517996
# 1        0.154895   0.047315     0.856767        1.000000    0.516611
# 2       15.983620   6.643777    85.495660        0.117975    0.686877
# 3       35.336125  13.611433   240.822486        0.018917    0.705795
# 4       33.057474  15.620499   157.632484        0.161563    0.681525
# ...           ...        ...          ...             ...         ...
# 1213     8.820031   0.001036    79.946280        1.000000    0.524640
# 1214     0.039767   0.000069     0.369746        0.471623    0.515319
# 1215     0.177561   0.009452     0.755977        1.000000    0.654393
# 1216  1077.764252   0.093515  5302.913608        1.000000    0.619970
# 1217     0.000872   0.000013     0.007314        0.077728    0.654854
#
#       volume_corr
# 0        0.037515
# 1        0.099032
# 2        0.973238
# 3        0.842114
# 4        0.950909
# ...           ...
# 1213     0.070593
# 1214    -0.805811
# 1215    -0.634677
# 1216    -0.274001
# 1217    -0.872534
#
# [1218 rows x 9 columns]

# %%
# volume analysis
fs.volume_analysis(volume_feature='original_shape_VoxelVolume')

# %% [markdown]
# Example of volume precision-recall curve:
# ![](./data/images/vol_prc.png)

# %% [markdown]
# Example of volume Spearman correlation coefficients:
# ![](./data/images/vol_corr.png)

# %% [markdown]
# # Examples of feature set usage:

# %%
from features_set import features_set
import pandas as pd

# %% [markdown]
# ## Binary classes

# %%
# set up the parameters
parameters = {
    'feature_path': "./data/features/features.xlsx", # path to csv/xls file with features
    'outcome_path': "./data/features/extended_clinical_df.xlsx", #path to csv/xls file with outcome
    'patient_column': 'Patient', # name of column with patient id
    'patient_in_outcome_column': 'PatientID', # name of column with patient id in clinical data file
    'outcome_column': '1yearsurvival' # name of outcome column
}

# %%
# initialize feature set
fs = features_set(**parameters)
# Out:
# Number of observations: 149
# Class labels: ['0' '1']
# Classes balance: [0.4228187919463087, 0.5771812080536913]

# %%
# excluding patients with unknown outcome (in case they are represented)
fs.handle_nan(axis=0)
# Out:
# Number of observations: 149
# Class labels: ['0' '1']
# Classes balance: [0.4228187919463087, 0.5771812080536913]

# %%
# checking patients' names
# print ('Patients names: ', fs._patient_name)

# %%
fs._feature_outcome_dataframe
# Out:
#                                     original_shape_Elongation  \
# Patient
# LUNG1-001_20180209_CT_2_GTV-1_mask                   0.732658
# LUNG1-002_000000_GTV-1_mask                          0.878035
# LUNG1-002_20180526_CT_1_GTV-1_mask                   0.878035
# LUNG1-003_000000_GTV-1_mask                          0.544631
# LUNG1-003_20180209_CT_1_GTV-1_mask                   0.544631
# ...                                                       ...
# LUNG1-342_000000_GTV-1_mask                          0.974104
# LUNG1-343_000000_GTV-1_mask                          0.849862
# LUNG1-345_000000_GTV-1_mask                          0.851225
# LUNG1-347_000000_GTV-1_mask                          0.551685
# LUNG1-350_000000_GTV-1_mask                          0.465647
#
#                                     original_shape_Flatness  \
# Patient
# LUNG1-001_20180209_CT_2_GTV-1_mask                 0.548834
# LUNG1-002_000000_GTV-1_mask                        0.755488
# LUNG1-002_20180526_CT_1_GTV-1_mask                 0.755488
# LUNG1-003_000000_GTV-1_mask                        0.356597
# LUNG1-003_20180209_CT_1_GTV-1_mask                 0.356597
# ...                                                     ...
# LUNG1-342_000000_GTV-1_mask                        0.705922
# LUNG1-343_000000_GTV-1_mask                        0.612734
# LUNG1-345_000000_GTV-1_mask                        0.478765
# LUNG1-347_000000_GTV-1_mask                        0.447612
# LUNG1-350_000000_GTV-1_mask                        0.355253
#
#                                     original_shape_LeastAxisLength  \
# Patient
# LUNG1-001_20180209_CT_2_GTV-1_mask                       46.151744
# LUNG1-002_000000_GTV-1_mask                              70.110114
# LUNG1-002_20180526_CT_1_GTV-1_mask                       70.110114
# LUNG1-003_000000_GTV-1_mask                              25.559022
# LUNG1-003_20180209_CT_1_GTV-1_mask                       25.559022
# ...                                                            ...
# LUNG1-342_000000_GTV-1_mask                              31.213709
# LUNG1-343_000000_GTV-1_mask                              40.937354
# LUNG1-345_000000_GTV-1_mask                              28.770221
# LUNG1-347_000000_GTV-1_mask                              13.158653
# LUNG1-350_000000_GTV-1_mask                              20.188183
#
#                                     original_shape_MajorAxisLength  \
# Patient
# LUNG1-001_20180209_CT_2_GTV-1_mask                       84.090588
# LUNG1-002_000000_GTV-1_mask                              92.801132
# LUNG1-002_20180526_CT_1_GTV-1_mask                       92.801132
# LUNG1-003_000000_GTV-1_mask                              71.674815
# LUNG1-003_20180209_CT_1_GTV-1_mask                       71.674815
# ...                                                            ...
# LUNG1-342_000000_GTV-1_mask                              44.216933
# LUNG1-343_000000_GTV-1_mask                              66.810979
# LUNG1-345_000000_GTV-1_mask                              60.092622
# LUNG1-347_000000_GTV-1_mask                              29.397432
# LUNG1-350_000000_GTV-1_mask                              56.827618
#
#                                     original_shape_Maximum2DDiameterColumn  \
# Patient
# LUNG1-001_20180209_CT_2_GTV-1_mask                               95.336247
# LUNG1-002_000000_GTV-1_mask                                     116.931604
# LUNG1-002_20180526_CT_1_GTV-1_mask                              116.931604
# LUNG1-003_000000_GTV-1_mask                                      56.639209
# LUNG1-003_20180209_CT_1_GTV-1_mask                               56.639209
# ...                                                                    ...
# LUNG1-342_000000_GTV-1_mask                                      57.245087
# LUNG1-343_000000_GTV-1_mask                                      82.377181
# LUNG1-345_000000_GTV-1_mask                                      72.801099
# LUNG1-347_000000_GTV-1_mask                                      21.260292
# LUNG1-350_000000_GTV-1_mask                                      61.554854
#
#                                     original_shape_Maximum2DDiameterRow  \
# Patient
# LUNG1-001_20180209_CT_2_GTV-1_mask                            83.186537
# LUNG1-002_000000_GTV-1_mask                                  101.833197
# LUNG1-002_20180526_CT_1_GTV-1_mask                           101.833197
# LUNG1-003_000000_GTV-1_mask                                   83.528438
# LUNG1-003_20180209_CT_1_GTV-1_mask                            83.528438
# ...                                                                 ...
# LUNG1-342_000000_GTV-1_mask                                   55.659680
# LUNG1-343_000000_GTV-1_mask                                   79.246451
# LUNG1-345_000000_GTV-1_mask                                   64.815122
# LUNG1-347_000000_GTV-1_mask                                   34.481879
# LUNG1-350_000000_GTV-1_mask                                   42.953463
#
#                                     original_shape_Maximum2DDiameterSlice  \
# Patient
# LUNG1-001_20180209_CT_2_GTV-1_mask                              95.425364
# LUNG1-002_000000_GTV-1_mask                                    104.316825
# LUNG1-002_20180526_CT_1_GTV-1_mask                             104.316825
# LUNG1-003_000000_GTV-1_mask                                     62.265560
# LUNG1-003_20180209_CT_1_GTV-1_mask                              62.265560
# ...                                                                   ...
# LUNG1-342_000000_GTV-1_mask                                     55.659680
# LUNG1-343_000000_GTV-1_mask                                     71.400280
# LUNG1-345_000000_GTV-1_mask                                     67.268120
# LUNG1-347_000000_GTV-1_mask                                     24.041631
# LUNG1-350_000000_GTV-1_mask                                     37.336309
#
#                                     original_shape_Maximum3DDiameter  \
# Patient
# LUNG1-001_20180209_CT_2_GTV-1_mask                         96.104110
# LUNG1-002_000000_GTV-1_mask                               125.674182
# LUNG1-002_20180526_CT_1_GTV-1_mask                        125.674182
# LUNG1-003_000000_GTV-1_mask                                84.011904
# LUNG1-003_20180209_CT_1_GTV-1_mask                         84.011904
# ...                                                              ...
# LUNG1-342_000000_GTV-1_mask                                60.183054
# LUNG1-343_000000_GTV-1_mask                                88.600226
# LUNG1-345_000000_GTV-1_mask                                74.155243
# LUNG1-347_000000_GTV-1_mask                                36.124784
# LUNG1-350_000000_GTV-1_mask                                65.886266
#
#                                     original_shape_MeshVolume  \
# Patient
# LUNG1-001_20180209_CT_2_GTV-1_mask              155379.500000
# LUNG1-002_000000_GTV-1_mask                     358446.791667
# LUNG1-002_20180526_CT_1_GTV-1_mask              358446.791667
# LUNG1-003_000000_GTV-1_mask                      34987.000000
# LUNG1-003_20180209_CT_1_GTV-1_mask               34987.000000
# ...                                                       ...
# LUNG1-342_000000_GTV-1_mask                      38986.875000
# LUNG1-343_000000_GTV-1_mask                     100987.458333
# LUNG1-345_000000_GTV-1_mask                      58463.250000
# LUNG1-347_000000_GTV-1_mask                       3131.208333
# LUNG1-350_000000_GTV-1_mask                      17831.708333
#
#                                     original_shape_MinorAxisLength  ...  \
# Patient                                                             ...
# LUNG1-001_20180209_CT_2_GTV-1_mask                       61.609664  ...
# LUNG1-002_000000_GTV-1_mask                              81.482668  ...
# LUNG1-002_20180526_CT_1_GTV-1_mask                       81.482668  ...
# LUNG1-003_000000_GTV-1_mask                              39.036358  ...
# LUNG1-003_20180209_CT_1_GTV-1_mask                       39.036358  ...
# ...                                                            ...  ...
# LUNG1-342_000000_GTV-1_mask                              43.071892  ...
# LUNG1-343_000000_GTV-1_mask                              56.780113  ...
# LUNG1-345_000000_GTV-1_mask                              51.152343  ...
# LUNG1-347_000000_GTV-1_mask                              16.218112  ...
# LUNG1-350_000000_GTV-1_mask                              26.461633  ...
#
#                                     wavelet-LLL_gldm_HighGrayLevelEmphasis  \
# Patient
# LUNG1-001_20180209_CT_2_GTV-1_mask                            14462.536758
# LUNG1-002_000000_GTV-1_mask                                   13208.125493
# LUNG1-002_20180526_CT_1_GTV-1_mask                            13208.125493
# LUNG1-003_000000_GTV-1_mask                                    9142.646956
# LUNG1-003_20180209_CT_1_GTV-1_mask                             9142.646956
# ...                                                                    ...
# LUNG1-342_000000_GTV-1_mask                                    8810.961714
# LUNG1-343_000000_GTV-1_mask                                    7974.212295
# LUNG1-345_000000_GTV-1_mask                                    9674.701245
# LUNG1-347_000000_GTV-1_mask                                    5185.837607
# LUNG1-350_000000_GTV-1_mask                                    7741.398468
#
#                                     wavelet-LLL_gldm_LargeDependenceEmphasis  \
# Patient
# LUNG1-001_20180209_CT_2_GTV-1_mask                                 33.609142
# LUNG1-002_000000_GTV-1_mask                                        55.600107
# LUNG1-002_20180526_CT_1_GTV-1_mask                                 55.600107
# LUNG1-003_000000_GTV-1_mask                                        17.909008
# LUNG1-003_20180209_CT_1_GTV-1_mask                                 17.909008
# ...                                                                      ...
# LUNG1-342_000000_GTV-1_mask                                        10.006351
# LUNG1-343_000000_GTV-1_mask                                        49.051197
# LUNG1-345_000000_GTV-1_mask                                        36.001759
# LUNG1-347_000000_GTV-1_mask                                         3.649573
# LUNG1-350_000000_GTV-1_mask                                        19.415632
#
#                                     wavelet-LLL_gldm_LargeDependenceHighGrayLevelEmphasis  \
# Patient
# LUNG1-001_20180209_CT_2_GTV-1_mask                                      548084.071741
# LUNG1-002_000000_GTV-1_mask                                             832176.248523
# LUNG1-002_20180526_CT_1_GTV-1_mask                                      832176.248523
# LUNG1-003_000000_GTV-1_mask                                             209143.444093
# LUNG1-003_20180209_CT_1_GTV-1_mask                                      209143.444093
# ...                                                                               ...
# LUNG1-342_000000_GTV-1_mask                                             104482.381761
# LUNG1-343_000000_GTV-1_mask                                             402459.929585
# LUNG1-345_000000_GTV-1_mask                                             394648.688745
# LUNG1-347_000000_GTV-1_mask                                              25163.108895
# LUNG1-350_000000_GTV-1_mask                                             178324.908140
#
#                                     wavelet-LLL_gldm_LargeDependenceLowGrayLevelEmphasis  \
# Patient
# LUNG1-001_20180209_CT_2_GTV-1_mask                                           0.002759
# LUNG1-002_000000_GTV-1_mask                                                  0.004497
# LUNG1-002_20180526_CT_1_GTV-1_mask                                           0.004497
# LUNG1-003_000000_GTV-1_mask                                                  0.002673
# LUNG1-003_20180209_CT_1_GTV-1_mask                                           0.002673
# ...                                                                               ...
# LUNG1-342_000000_GTV-1_mask                                                  0.001182
# LUNG1-343_000000_GTV-1_mask                                                  0.006028
# LUNG1-345_000000_GTV-1_mask                                                  0.003500
# LUNG1-347_000000_GTV-1_mask                                                  0.001458
# LUNG1-350_000000_GTV-1_mask                                                  0.002380
#
#                                     wavelet-LLL_gldm_LowGrayLevelEmphasis  \
# Patient
# LUNG1-001_20180209_CT_2_GTV-1_mask                               0.000139
# LUNG1-002_000000_GTV-1_mask                                      0.000162
# LUNG1-002_20180526_CT_1_GTV-1_mask                               0.000162
# LUNG1-003_000000_GTV-1_mask                                      0.000367
# LUNG1-003_20180209_CT_1_GTV-1_mask                               0.000367
# ...                                                                   ...
# LUNG1-342_000000_GTV-1_mask                                      0.000208
# LUNG1-343_000000_GTV-1_mask                                      0.000158
# LUNG1-345_000000_GTV-1_mask                                      0.000198
# LUNG1-347_000000_GTV-1_mask                                      0.000878
# LUNG1-350_000000_GTV-1_mask                                      0.000274
#
#                                     wavelet-LLL_gldm_SmallDependenceEmphasis  \
# Patient
# LUNG1-001_20180209_CT_2_GTV-1_mask                                  0.267761
# LUNG1-002_000000_GTV-1_mask                                         0.188931
# LUNG1-002_20180526_CT_1_GTV-1_mask                                  0.188931
# LUNG1-003_000000_GTV-1_mask                                         0.402930
# LUNG1-003_20180209_CT_1_GTV-1_mask                                  0.402930
# ...                                                                      ...
# LUNG1-342_000000_GTV-1_mask                                         0.412647
# LUNG1-343_000000_GTV-1_mask                                         0.124182
# LUNG1-345_000000_GTV-1_mask                                         0.259454
# LUNG1-347_000000_GTV-1_mask                                         0.663799
# LUNG1-350_000000_GTV-1_mask                                         0.388809
#
#                                     wavelet-LLL_gldm_SmallDependenceHighGrayLevelEmphasis  \
# Patient
# LUNG1-001_20180209_CT_2_GTV-1_mask                                        2959.571494
# LUNG1-002_000000_GTV-1_mask                                               1733.836805
# LUNG1-002_20180526_CT_1_GTV-1_mask                                        1733.836805
# LUNG1-003_000000_GTV-1_mask                                               2838.784544
# LUNG1-003_20180209_CT_1_GTV-1_mask                                        2838.784544
# ...                                                                               ...
# LUNG1-342_000000_GTV-1_mask                                               3056.038922
# LUNG1-343_000000_GTV-1_mask                                                838.463963
# LUNG1-345_000000_GTV-1_mask                                               1811.133205
# LUNG1-347_000000_GTV-1_mask                                               2953.583448
# LUNG1-350_000000_GTV-1_mask                                               2337.815795
#
#                                     wavelet-LLL_gldm_SmallDependenceLowGrayLevelEmphasis  \
# Patient
# LUNG1-001_20180209_CT_2_GTV-1_mask                                           0.000058
# LUNG1-002_000000_GTV-1_mask                                                  0.000053
# LUNG1-002_20180526_CT_1_GTV-1_mask                                           0.000053
# LUNG1-003_000000_GTV-1_mask                                                  0.000191
# LUNG1-003_20180209_CT_1_GTV-1_mask                                           0.000191
# ...                                                                               ...
# LUNG1-342_000000_GTV-1_mask                                                  0.000126
# LUNG1-343_000000_GTV-1_mask                                                  0.000049
# LUNG1-345_000000_GTV-1_mask                                                  0.000108
# LUNG1-347_000000_GTV-1_mask                                                  0.000784
# LUNG1-350_000000_GTV-1_mask                                                  0.000185
#
#                                            ROI  1yearsurvival
# Patient
# LUNG1-001_20180209_CT_2_GTV-1_mask  GTV-1_mask              1
# LUNG1-002_000000_GTV-1_mask         GTV-1_mask              0
# LUNG1-002_20180526_CT_1_GTV-1_mask  GTV-1_mask              0
# LUNG1-003_000000_GTV-1_mask         GTV-1_mask              0
# LUNG1-003_20180209_CT_1_GTV-1_mask  GTV-1_mask              0
# ...                                        ...            ...
# LUNG1-342_000000_GTV-1_mask         GTV-1_mask              0
# LUNG1-343_000000_GTV-1_mask         GTV-1_mask              0
# LUNG1-345_000000_GTV-1_mask         GTV-1_mask              1
# LUNG1-347_000000_GTV-1_mask         GTV-1_mask              1
# LUNG1-350_000000_GTV-1_mask         GTV-1_mask              1
#
# [149 rows x 1220 columns]

# %%
# visualization of feature values distribution in classes (in .html report)
fs.plot_distribution(fs._feature_column[:100])

# %% [markdown]
# Example of plotted distributions of feature values in classes:
# ![](./data/images/distr.png)

# %%
# visualization of feature mutual (Spearman) correlation coefficient matrix (in .html report)
fs.plot_correlation_matrix(fs._feature_column[:100])

# %% [markdown]
# Example of feature correlation matrix:
# ![](./data/images/corr.png)

# %%
# visualization of Mann-Whitney Bonferroni corrected p-values for binary classes test (in .html report)
fs.plot_MW_p(fs._feature_column[:100])

# %% [markdown]
# Example of Mann-Whitney p-values:
# ![](./data/images/p_MW.png)

# %%
# visualization of univariate ROC-curves (in .html report)
fs.plot_univariate_roc(fs._feature_column[:100])

# %% [markdown]
# Example of univariate feature ROC:
# ![](./data/images/roc.png)

# %%
# calculation of basic statistics for each feature (in .xlsx):
# number of NaN, mean, std, min, max; if applicable: MW-p, univariate ROC AUC, volume correlation
fs.calculate_basic_stats(volume_feature='original_shape_VoxelVolume')

# %%
# checking the excel table
print('Basic statistics for each feature')
pd.read_excel('./data/features/features_basic_stats.xlsx')
# Out:
# Basic statistics for each feature
#                                              Unnamed: 0  NaN         Mean  \
# 0                             original_shape_Elongation    0     0.720328
# 1                               original_shape_Flatness    0     0.559677
# 2                        original_shape_LeastAxisLength    0    32.055804
# 3                        original_shape_MajorAxisLength    0    61.595666
# 4                original_shape_Maximum2DDiameterColumn    0    63.064956
# ...                                                 ...  ...          ...
# 1213  wavelet-LLL_gldm_LargeDependenceLowGrayLevelEm...    0     1.646810
# 1214              wavelet-LLL_gldm_LowGrayLevelEmphasis    0     0.007969
# 1215           wavelet-LLL_gldm_SmallDependenceEmphasis    0     0.313546
# 1216  wavelet-LLL_gldm_SmallDependenceHighGrayLevelE...    0  2431.019809
# 1217  wavelet-LLL_gldm_SmallDependenceLowGrayLevelEm...    0     0.000440
#
#               Std        Min          Max  p_MW_corrected  univar_auc  \
# 0        0.161721   0.062127     0.974104        1.000000    0.533869
# 1        0.154895   0.047315     0.856767        1.000000    0.532484
# 2       15.983620   6.643777    85.495660        0.117975    0.686877
# 3       35.336125  13.611433   240.822486        0.018917    0.694168
# 4       33.057474  15.620499   157.632484        0.161563    0.658269
# ...           ...        ...          ...             ...         ...
# 1213     8.820031   0.001036    79.946280        1.000000    0.540513
# 1214     0.039767   0.000069     0.369746        0.471623    0.531192
# 1215     0.177561   0.009452     0.755977        1.000000    0.654393
# 1216  1077.764252   0.093515  5302.913608        1.000000    0.619970
# 1217     0.000872   0.000013     0.007314        0.077728    0.670727
#
#       volume_corr
# 0        0.037515
# 1        0.099032
# 2        0.973238
# 3        0.842114
# 4        0.950909
# ...           ...
# 1213     0.070593
# 1214    -0.805811
# 1215    -0.634677
# 1216    -0.274001
# 1217    -0.872534
#
# [1218 rows x 9 columns]

# %%
# volume analysis
fs.volume_analysis(volume_feature='original_shape_VoxelVolume')

# %% [markdown]
# Example of volume precision-recall curve:
# ![](./data/images/vol_prc.png)

# %% [markdown]
# Example of volume Spearman correlation coefficients:
# ![](./data/images/vol_corr.png)

# %% [markdown]
# ## Multi-class

# %%
parameters = {
    'feature_path': "./data/features/features.xlsx", # path to csv/xls file with features
    'outcome_path': "./data/features/extended_clinical_df.xlsx", #path to csv/xls file with outcome
    'patient_column': 'Patient', # name of column with patient id
    'patient_in_outcome_column': 'PatientID', # name of column with patient id in clinical data file
    'outcome_column': 'Overall.Stage' # name of outcome column
}

# %%
fs = features_set(**parameters)
# Out:
# Number of observations: 149
# Class labels: ['I' 'II' 'IIIa' 'IIIb' 'nan']
# Classes balance: [0.24161073825503357, 0.09395973154362416, 0.2348993288590604, 0.4228187919463087, 0.006711409395973154]

# %%
fs._feature_outcome_dataframe[fs._feature_outcome_dataframe['Overall.Stage'].isnull()]
# Out:
#                              original_shape_Elongation  \
# Patient
# LUNG1-272_000000_GTV-1_mask                   0.713259
#
#                              original_shape_Flatness  \
# Patient
# LUNG1-272_000000_GTV-1_mask                 0.487347
#
#                              original_shape_LeastAxisLength  \
# Patient
# LUNG1-272_000000_GTV-1_mask                         14.2573
#
#                              original_shape_MajorAxisLength  \
# Patient
# LUNG1-272_000000_GTV-1_mask                       29.254915
#
#                              original_shape_Maximum2DDiameterColumn  \
# Patient
# LUNG1-272_000000_GTV-1_mask                               25.495098
#
#                              original_shape_Maximum2DDiameterRow  \
# Patient
# LUNG1-272_000000_GTV-1_mask                            31.400637
#
#                              original_shape_Maximum2DDiameterSlice  \
# Patient
# LUNG1-272_000000_GTV-1_mask                              35.608988
#
#                              original_shape_Maximum3DDiameter  \
# Patient
# LUNG1-272_000000_GTV-1_mask                         37.868192
#
#                              original_shape_MeshVolume  \
# Patient
# LUNG1-272_000000_GTV-1_mask                5713.416667
#
#                              original_shape_MinorAxisLength  ...  \
# Patient                                                      ...
# LUNG1-272_000000_GTV-1_mask                        20.86634  ...
#
#                              wavelet-LLL_gldm_HighGrayLevelEmphasis  \
# Patient
# LUNG1-272_000000_GTV-1_mask                            11955.686684
#
#                              wavelet-LLL_gldm_LargeDependenceEmphasis  \
# Patient
# LUNG1-272_000000_GTV-1_mask                                 27.442472
#
#                              wavelet-LLL_gldm_LargeDependenceHighGrayLevelEmphasis  \
# Patient
# LUNG1-272_000000_GTV-1_mask                                      349332.116971
#
#                              wavelet-LLL_gldm_LargeDependenceLowGrayLevelEmphasis  \
# Patient
# LUNG1-272_000000_GTV-1_mask                                           0.002377
#
#                              wavelet-LLL_gldm_LowGrayLevelEmphasis  \
# Patient
# LUNG1-272_000000_GTV-1_mask                                0.00028
#
#                              wavelet-LLL_gldm_SmallDependenceEmphasis  \
# Patient
# LUNG1-272_000000_GTV-1_mask                                  0.233726
#
#                              wavelet-LLL_gldm_SmallDependenceHighGrayLevelEmphasis  \
# Patient
# LUNG1-272_000000_GTV-1_mask                                        2319.671592
#
#                              wavelet-LLL_gldm_SmallDependenceLowGrayLevelEmphasis  \
# Patient
# LUNG1-272_000000_GTV-1_mask                                           0.000215
#
#                                     ROI  Overall.Stage
# Patient
# LUNG1-272_000000_GTV-1_mask  GTV-1_mask            NaN
#
# [1 rows x 1220 columns]

# %%
fs.handle_nan(axis=0)
# Out:
# Number of observations: 148
# Class labels: ['I' 'II' 'IIIa' 'IIIb']
# Classes balance: [0.24324324324324326, 0.0945945945945946, 0.23648648648648649, 0.42567567567567566]

# %%
fs.plot_distribution(fs._feature_column[:100])

# %%
fs.plot_distribution(fs._feature_column[:100], ['I', 'IIIb'])

# %%
fs.plot_correlation_matrix(fs._feature_column[:100])

# %%
fs.plot_MW_p(fs._feature_column[:100], ['I', 'IIIb'])

# %%
fs.plot_univariate_roc(fs._feature_column[:100], ['I', 'IIIb'])

# %%
fs.calculate_basic_stats(volume_feature='original_shape_VoxelVolume')

# %%
fs.volume_analysis(volume_feature='original_shape_VoxelVolume')
